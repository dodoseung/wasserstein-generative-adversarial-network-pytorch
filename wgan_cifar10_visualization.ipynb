# %%
from wgan import WGAN

import torch
import matplotlib.pyplot as plt
import numpy as np

from utils import load_model, load_yaml

# %%
# Set the configuration
config = load_yaml("/home/seungwon/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/config/wgan_cifar10_config.yml")

# Training setting
device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(config['data']['seed'])
if device == 'cuda':
  torch.cuda.manual_seed_all(config['data']['seed'])

# Set the model
model = WGAN(gen_latent_z=config['model']['gen_latent_z'], gen_init_layer=config['model']['gen_init_layer'],
            gen_conv_trans=config['model']['gen_conv_trans'], gen_conv_filters=config['model']['gen_conv_filters'],
            gen_conv_kernels=config['model']['gen_conv_kernels'], gen_conv_strides=config['model']['gen_conv_strides'],
            gen_conv_pads=config['model']['gen_conv_pads'],gen_dropout_rate=config['model']['gen_dropout_rate'],
            crt_input_img=config['model']['crt_input_img'], crt_conv_filters=config['model']['crt_conv_filters'],
            crt_conv_kernels=config['model']['crt_conv_kernels'], crt_conv_strides=config['model']['crt_conv_strides'],
            crt_conv_pads=config['model']['crt_conv_pads'], crt_dropout_rate=config['model']['crt_dropout_rate']).to(device)
model, _, _, _ = load_model('/home/seungwon/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/models/cifar10/2023.08.01.17.32.06/cifar10_last.pt', model)
print(model)
# Out:
# Load the yaml file from /home/seungwon/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/config/wgan_cifar10_config.yml
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/seungwon/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/wgan_cifar10_visualization.ipynb Cell 2 in <cell line: 18>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bmainserver1/home/seungwon/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/wgan_cifar10_visualization.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> # Set the model
#      <a href='vscode-notebook-cell://ssh-remote%2Bmainserver1/home/seungwon/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/wgan_cifar10_visualization.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> model = WGAN(gen_latent_z=config['model']['gen_latent_z'], gen_init_layer=config['model']['gen_init_layer'],
#      <a href='vscode-notebook-cell://ssh-remote%2Bmainserver1/home/seungwon/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/wgan_cifar10_visualization.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>             gen_conv_trans=config['model']['gen_conv_trans'], gen_conv_filters=config['model']['gen_conv_filters'],
#      <a href='vscode-notebook-cell://ssh-remote%2Bmainserver1/home/seungwon/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/wgan_cifar10_visualization.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>             gen_conv_kernels=config['model']['gen_conv_kernels'], gen_conv_strides=config['model']['gen_conv_strides'],
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2Bmainserver1/home/seungwon/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/wgan_cifar10_visualization.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>             crt_conv_kernels=config['model']['crt_conv_kernels'], crt_conv_strides=config['model']['crt_conv_strides'],
#      <a href='vscode-notebook-cell://ssh-remote%2Bmainserver1/home/seungwon/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/wgan_cifar10_visualization.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>             crt_conv_pads=config['model']['crt_conv_pads'], crt_dropout_rate=config['model']['crt_dropout_rate']).to(device)
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bmainserver1/home/seungwon/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/wgan_cifar10_visualization.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> model, _, _, _ = load_model('/home/seungwon/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/models/cifar10/2023.08.01.17.24.28/cifar10_last.pt', model)
#      <a href='vscode-notebook-cell://ssh-remote%2Bmainserver1/home/seungwon/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/wgan_cifar10_visualization.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> print(model)
#
# File ~/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/utils.py:94, in load_model(model_path, model, optimizer)
#      91 PATH = model_path
#      93 # Get the checkpoint
# ---> 94 checkpoint = torch.load(PATH)
#      96 # Load the model
#      97 if model is not None:
#
# File ~/anaconda3/envs/cv/lib/python3.8/site-packages/torch/serialization.py:699, in load(f, map_location, pickle_module, **pickle_load_args)
#     696 if 'encoding' not in pickle_load_args.keys():
#     697     pickle_load_args['encoding'] = 'utf-8'
# --> 699 with _open_file_like(f, 'rb') as opened_file:
#     700     if _is_zipfile(opened_file):
#     701         # The zipfile reader is going to advance the current file position.
#     702         # If we want to actually tail call to torch.jit.load, we need to
#     703         # reset back to the original position.
#     704         orig_position = opened_file.tell()
#
# File ~/anaconda3/envs/cv/lib/python3.8/site-packages/torch/serialization.py:230, in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# File ~/anaconda3/envs/cv/lib/python3.8/site-packages/torch/serialization.py:211, in _open_file.__init__(self, name, mode)
#     210 def __init__(self, name, mode):
# --> 211     super(_open_file, self).__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/seungwon/Projects/deep-learning-projects/cv-07-wasserstein-generative-adversarial-network-pytorch/models/cifar10/2023.08.01.17.24.28/cifar10_last.pt'

# %%
n_to_show = 10
z_latent = config['model']['gen_latent_z']
np.random.seed(777)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
model.eval()

z = 2 * torch.rand(n_to_show, z_latent, device=device) - 1
img = model.G(z)

for i in range(n_to_show):     
    sub = fig.add_subplot(1, n_to_show, i+1)
    sub.axis('off')
    sub.imshow(img[i].permute(1, 2, 0).cpu().detach().numpy())
